# %%
import os
from dotenv import load_dotenv
load_dotenv()
token=os.getenv('api_key')

# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”
from transformers import pipeline
generator = pipeline('text-generation', model='gpt2', token=token)
print(generator("Artificial Intelligence will", max_length=30))

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”
# Import pipeline from transformers
from transformers import pipeline

# Create text generation pipeline using GPT-2
generator = pipeline("text-generation", model="gpt2")

# Prompt given by the game developer
prompt = "The hero enters the ancient forest and discovers"

# Generate story continuation
result = generator(prompt, max_length=50, num_return_sequences=1)

# Print the generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers a man who is still a child. He is very powerful, and the man he calls his father is the god of the man. He is the god of the sky, and the gods of the earth. He is the god of the sun, and the sun of the earth. He is the god of the earth, and the earth of the gods. He is the god of the stars, and the stars of the heaven. He is the god of the sea, and the sea of the gods. He is the god of the stars, and the stars of the heaven. He is the god of the earth, and the earth of the gods.
#
# He is the god of the moon, and the moon of the earth. He is the god of the stars, and the stars of the heaven. He is the god of the sun, and the sun of the earth. He is the god of the stars, and the stars of the heaven. He is the god of the earth, and the earth of the gods.
#
# He is the god of the night, and the night of the gods. He is the god of the stars, and the stars of the heaven. He is the god of the earth, and the earth of the gods.

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:
from transformers import AutoTokenizer

# 1. Load the pre-trained BERT tokenizer
# "uncased" means it will treat "Pain" and "pain" the same way
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# 2. Define the patient's query
patient_query = "I have chest pain and shortness of breath"

# 3. Break the sentence into tokens (WordPieces)
# This handles medical terms by splitting them if they aren't in the vocabulary
tokens = tokenizer.tokenize(patient_query)

# 4. Convert tokens to numerical IDs
# These IDs are what the actual BERT model "sees" and processes
token_ids = tokenizer.convert_tokens_to_ids(tokens)

# Output the results
print(f"Patient Query: {patient_query}")
print(f"Tokens: {tokens}")
print(f"Token IDs: {token_ids}")
# Out:
# Patient Query: I have chest pain and shortness of breath
# Tokens: ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']
# Token IDs: [1045, 2031, 3108, 3255, 1998, 2460, 2791, 1997, 3052]

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI experts.\n\nThe future of Artificial Intelligence is in the hands of the next generation of'}]
# [{'generated_text': 'The future of Artificial Intelligence, which promises to replace humans as the driving force behind artificial intelligence and AI for the next few decades, is unclear.\n\n"What we\'re seeing in this time is a gradual decline in the number of artificial intelligence projects," said Chris Cray, a professor at the University of Chicago\'s department of computer science, computer engineering and artificial intelligence. "People\'s lives are increasingly affected by these projects because of the potential for change."\n\nThe number of projects has been growing steadily since the start of the year and Cray said there are about half a million projects in the works, which will offer solutions to complex problems.\n\n"We\'re seeing a lot of big projects on the horizon, but for now we\'re just waiting to see what happens with the pace of the progress," he said.'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling
from transformers import pipeline

# Load GPT-2 model for text generation
generator = pipeline("text-generation", model="gpt2")

# Prompt given by the writer
prompt = "The future of Artificial Intelligence"

# Generate text with low temperature (more predictable)
low_temp_output = generator(
    prompt,
    max_length=40,
    temperature=0.2,
    num_return_sequences=1
)

# Generate text with high temperature (more creative)
high_temp_output = generator(
    prompt,
    max_length=40,
    temperature=0.8,
    num_return_sequences=1
)

print("Low Temperature Output (0.2):")
print(low_temp_output[0]["generated_text"])

print("\nHigh Temperature Output (0.8):")
print(high_temp_output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Low Temperature Output (0.2):
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is in the hands of the people.
#
# The future of Artificial Intelligence is
#
# High Temperature Output (0.8):
# The future of Artificial Intelligence can't be written away in a paper. Just as there is a real world AI, there is a real world AI. There is a real world AI where you can get any number of the things that you want, which means you can do it at your own pace, which makes the whole world a lot more like a game.
#
# We can't say that, but I think those are pretty big words. You know, if you have an AI that is incredibly smart, you can think that about. It's just a very smart AI. That's what we're trying to do, and we believe that is what is driving the growth of AI.
#
# The goal of AI is to make things more natural.
#
# So what do you mean by this?
#
# I think we are trying to get it to make what it wants to make better. You can be a robot and you can be an AI and you can be a human. The problem is, we need to think about what makes what it wants to make better. And that's what we're doing, and that's what we're pushing to do.
#
# So as far as how we're doing it, we're doing it at the speed of light, I think.

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a prompt:  he future of Artificial Intelligence will reshape industries, redefine creativity, and challenge #  our understanding of human potential
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# he future of Artificial Intelligence will reshape industries, redefine creativity, and challenge #  our understanding of human potential.
#
# We are committed to helping you, and your business, stay informed and effective. We're also offering our services to help you do the same. We value your feedback and we want to hear your ideas and suggestions. Our services include:
#
# • Access to a huge library of data and insights from your business on a daily basis.
#
# • Customize your business with our unique business analytics.
#
# • Track your business results using our comprehensive financial management tools.
#
# • Collaborate with others to build a more effective and efficient business.
#
# • Create the right solutions in your business that make your business more efficient and more productive.
#
# In addition to our services, we also offer an app for Android and iOS.
#
# We will continue to provide the information you need, as well as offering your business with an app that you can use.
#
# In the meantime, please help us keep our company alive by following us on Facebook and Twitter.

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

from transformers import pipeline

# Load GPT-2 model
generator = pipeline("text-generation", model="gpt2")

# Ask student to enter prompt
prompt = input("Enter a prompt: ")

# Generate essay continuation
result = generator(prompt, max_length=50, num_return_sequences=1)

# Print generated text
print("\nGenerated Essay Idea:")
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a prompt:  The impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Essay Idea:
# The impact of technology on education has been profound. In the past, there was an emphasis on the importance of teaching. Now, many students believe that it is simply too late to teach.
#
# In the United States alone, the percentage of high school students who are exposed to technology has dropped to 14.6 percent of the U.S. total between 1995 and 2000.
#
# A recent study by the American Association of University Professors and the Harvard Business School found that of the 3,000 American high school students who were exposed to high tech, 6,000 were taught about the importance of technology.
#
# Another study by the Stanford University Center for Technology Policy and Management found that about half of students in the top 10 percent of high school graduates have never heard of technology.
#
# So what does this mean for the future of education?
#
# While the world is changing rapidly, we still have a long way to go. We need to find ways of reducing our reliance on technology to create a sustainable, sustainable future.
#
# Read or Share this story: http://usat.ly/1m1kPkT

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# D:\anaconda\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\HP\.cache\huggingface\hub\models--distilgpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform the way corporations and other institutions interact with one another and our society. In fact, there are more than 100 companies that use AI to develop products and services including social network management, data analytics, and cloud computing.\n\nIn short, AI will change the way businesses and governments interact with one another. This is exactly what Musk and other leading entrepreneurs have been making for the last six years.\n\nIt is a major breakthrough that will transform the way organizations interact with one another. It will open up new markets for a range of new businesses. It will expand the social and organizational possibilities for the next generation of leaders.\n\nThis is what Musk and his team have been doing for more than a decade.\n\nThey have brought together the world's top thinkers, engineers, entrepreneurs and philanthropists, as well as the most powerful minds in the tech world.\n\nThey have built a global network of organizations that will transform the way companies and governments interact and work.\n\nThey have created a new era of collaboration in the tech industry.\n\nAnd they have created a new future for the way we interact with one another.\n\nThey have built a world where people and companies can freely share information on everything from robotics and cloud computing to energy and technology."}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform you more and more. In the next six years, Artificial Intelligence will be able to make you want to be more or less as well as your friends.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.
from transformers import pipeline

# Load two AI models
gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

# Prompt given by the teacher
prompt = "LLM is a generative AI model that generates and understands human language."

# Generate output from GPT-2
gpt2_output = gpt2(prompt, max_length=40, num_return_sequences=1)

# Generate output from DistilGPT-2
distil_output = distilgpt2(prompt, max_length=40, num_return_sequences=1)

# Print outputs
print("GPT-2 Output:")
print(gpt2_output[0]["generated_text"])

print("\nDistilGPT-2 Output:")
print(distil_output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# LLM is a generative AI model that generates and understands human language. It provides a full suite of expressive control, and the models are based on a subset of languages that are able to be used to simulate human language.
#
# The C# framework is written in C#, and the implementation of the C# framework is available on GitHub.
#
# A C# compiler is available from https://github.com/Samples/C#DependencyInjection
#
# A C# compiler is available from https://github.com/Samples/C#Samples
#
# A C# compiler is available from https://github.com/Samples/C#Tutorials
#
# A C# compiler is available from https://github.com/Samples/C#Tutorials
#
# A C# compiler is available from https://github.com/Samples/C#Tutorials
#
# A C# compiler is available from https://github.com/Samples/C#Tutorials
#
# A C# compiler is available from https://github.com/Samples/C#Tutorials
#
# DistilGPT-2 Output:
# LLM is a generative AI model that generates and understands human language. We believe that the current approach to AI is to use general AI as a basis for defining and generating neural neural networks. This approach is based on a method called neural network classification.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# M is a generative AI model that does not rely on the general language syntax. Instead, it uses the general language syntax.
# In the following examples, the code generated using a generative AI dataset is generated from the current model in a neural network classification.
# The code using the generative AI dataset is generated in a neural network classification. The code generated from the neural network classification is generated in a neural network classification.
# The code generated from the neural network classification is generated in a neural network classification.
# The code generated from the Neural network classification is generated in a neural network classification.
# The code generated from the neural network classification is generated in a neural network classification.
# The code generated from the neural network classification is generated in a neural network classification.
# The code generated from the neural network classification is generated in a neural network classification.
# The code generated from the neural network classification is generated in a neural network classification.
# The code generated from the neural network classification is
